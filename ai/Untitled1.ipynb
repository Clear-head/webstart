# %% [markdown]
# <a href="https://colab.research.google.com/github/Clear-head/webstart/blob/main/ai/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow==2.12.0
#세션 다시 시작해야 한다.
# Out:
# Requirement already satisfied: tensorflow==2.12.0 in /usr/local/lib/python3.11/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.71.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (3.13.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (4.25.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (4.13.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12.0) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.12.0) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12.0) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12.0) (3.2.2)

# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np
import tensorflow as tf

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# %%
# Load the model
model = load_model("keras_model.h5", compile=False, custom_objects={'DepthwiseConv2D': tf.keras.layers.DepthwiseConv2D})

# %%
# Load the labels
class_names = open("labels.txt", "r").readlines()

# %%
# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# Replace this with the path to your image

image = Image.open("180.jpg").convert("RGB")

# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

# turn the image into a numpy array
image_array = np.asarray(image)

# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

# Load the image into the array
data[0] = normalized_image_array
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-a4e2f005704f> in <cell line: 0>()
#       6 # Replace this with the path to your image
#       7
# ----> 8 image = Image.open("180.jpg").convert("RGB")
#       9
#      10 # resizing the image to be at least 224x224 and then cropping from the center
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3503
#    3504     if filename:
# -> 3505         fp = builtins.open(filename, "rb")
#    3506         exclusive_fp = True
#    3507     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '180.jpg'

# %%
# prompt: 이미지 파일의 이름을 리스트로 저장

import os

# Specify the directory containing your image files
sad_image_directory = './sample_data/sad'  # Replace with the actual path to your images

# List all files in the directory
sad_all_files = os.listdir(sad_image_directory)

# Filter out files that are image files (you might need to adjust the extensions)
image_files = [f for f in sad_all_files if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]

# Print the list of image file names
image_files

# You can now use the 'image_files' list to iterate through the image files
# Out:
# ['Sad-man-being-consoled-by-friends-in-group-therapy.jpg',
#  'sad-man-holding-head-with-hand_1150-6345.jpg',
#  'depositphotos_86851530-stock-photo-close-up-of-african-young.jpg',
#  'portrait-sad-man-260nw-126009806.jpg',
#  'sad.jpg',
#  'crying-sad.gif',
#  'lonely-depressed-person-sitting-near-brick-wall_181624-30778.jpg',
#  'sad-quotes-about-life.jpg',
#  'Make-someone-sad-happy.jpg',
#  'rtor_guest-blog_fetured-image_Depression-versus-Sadness-How-to-Recognize-and-Cope.jpg',
#  'sad-looking-man.jpg',
#  'very-sad-man-sitting-alone-on-white-background-depressed-young-man-sitting-businessman-vector.jpg',
#  'depositphotos_11207956-stock-photo-thoughtful-man-in-the-living.jpg',
#  'sad-woman.jpg',
#  'How-To-Make-Someone-Happy-When-Theyre-Sad.jpg',
#  '640px-Crying-girl.jpg',
#  'sad-people-icon-2CCHXB2.jpg',
#  '-unhappy-miss-good-chance-dressed-casually-isolated-yellow-wall_273609-37534.jpg',
#  'sadness.jpg',
#  'Sadder-not-wiser_AdobeStock_219682170.jpg',
#  'dark-depression-mood-people-wallpaper-preview.jpg',
#  'image-20160914-4963-19knfh1.jpg',
#  '766x415_Depression_vs_Sadness-1-732x415.jpg',
#  'aid12707023-v4-1200px-Make-a-Sad-Person-Happy-Step-10.jpg',
#  'sad-people-vector-26812552.jpg',
#  '20201112-Alexithymia-844.jpg',
#  'file-20211126-25-4jc5ds.jpeg',
#  'a-man-who-suffers-from-seasonal-affective-disorder-walking-down-a-foggy-road.jpg',
#  'image18.jpeg',
#  '1694806.jpg',
#  'Sad-man-sitting-in-bedroom-header.jpg',
#  'CC_HE_1221887081_SituationalDepression-650x428.jpg',
#  'sadness-inside-out-today-main-tease-191018.jpg',
#  'mental-health_1200_getty.jpg',
#  'man-portrait-contemplative-sad-looking-at-camera-732x549-thumbnail.jpg',
#  'upsetman.jpg',
#  'depressed-man-studio-shot-260nw-404652526.jpg',
#  'man-tears-tear-look.jpg',
#  'man-with-head-down-300x300.jpg',
#  'iStock_000001932580XSmall.jpg',
#  '5acf9ed1146e711e008b46d7.jpg',
#  'coronavirus-depression-hero.jpg',
#  'what-successful-people-do-when-they-are-sad-1200x900.jpg',
#  '73705bd7debb66c2afc780a22c223804.jpg',
#  'sue.jpg',
#  'sad-glance-mm-nisan-kandilcioglu.jpg',
#  '39843138-sad-man.jpg',
#  'screen-shot-2014-07-31-at-6-09-12-pm.png',
#  'crying-at-work.jpg',
#  'all-those-people-who-are-sad-17573-1.jpg',
#  'vector-sad-man-sitting-silhouette.jpg',
#  '107188144-1675355909384-gettyimages-1302154722-dsc_9175.jpeg',
#  'what-to-say-to-someone-whos-depressed.jpg',
#  'sad-people-group-therapy-session_23-2148752071.jpg',
#  '09-113216-depressed_people_listen_to_sad_music_to_calm_and_uplift_says_study.jpg',
#  'n-rendering-frustrated-upset-man-sitting-white-people-man-character-53250684.jpg',
#  'pexels-photo-4584665.jpeg',
#  'dreamstime_s_101440985.jpg',
#  'sad-quotes-lead-image-1677524157.jpg',
#  'person-super-depressed.jpg',
#  '_2539df08-4f50-11e6-85e3-522dd231fa74.jpg',
#  'Science_robotgait_124649246.jpg',
#  'image-asset.jpeg',
#  'secret-signs-of-loneliness-01-1440x810.jpg',
#  'b2ap3_large_happy-sad-unsplash-850x575.jpg',
#  'people-1492052_1920-1024x681.jpg',
#  'isolated-girl-crying-over-makeup-sad-person-concept-isolated-white-174239618.jpg',
#  'sad-people.jpg',
#  '0x0.jpg',
#  'strated-depressed-man-sitting-on-plastic-stool-3d-white-people-man-character.jpg',
#  '405-4050267_sad-people-png-sad-person-transparent-background-png.png',
#  'depression-1020x680.jpg',
#  'african-american-depressive-sad-broken-260nw-475790911.jpg',
#  'png-transparent-woman-sad-folklore-ghost-horror-spirit-vendetta-vengeance-girl-person-thumbnail.png',
#  '360_F_548848756_IlV9Y9HV8chb6mSuc3PBamYRT9gIn8Vo.jpg',
#  '7RNXwSxCAKL8vGtXG2ZkyD-1200-80.jpg',
#  'sad-person-concept-vector-26538685.jpg',
#  'sad-person-pictures-2bnso9uiwlhrikrx.jpg',
#  'Seasonal-affective-disorder.png']

# %%
# prompt: image_files 를 이용한 예측

# Specify the directory containing your image files
image_directory = './sample_data/sad'  # Replace with the actual path to your images

# List all files in the directory
all_files = os.listdir(image_directory)

# Filter out files that are image files (you might need to adjust the extensions)
image_files = [f for f in all_files if f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]

# You can now use the 'image_files' list to iterate through the image files
for image_file in image_files:
    image_path = os.path.join(image_directory, image_file)

    image = Image.open(image_path).convert("RGB")

    # resizing the image to be at least 224x224 and then cropping from the center
    size = (224, 224)
    image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

    # turn the image into a numpy array
    image_array = np.asarray(image)

    # Normalize the image
    normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

    # Load the image into the array
    data[0] = normalized_image_array

    # Predicts the model
    prediction = model.predict(data)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Print prediction and confidence score for the current image
    print(f"Image: {image_file}")
    print("Class:", class_name[2:], end="")
    print("Confidence Score:", confidence_score)
    print("-" * 20) # Separator for clarity
# Out:
# 1/1 [==============================] - 1s 991ms/step
# Image: Sad-man-being-consoled-by-friends-in-group-therapy.jpg
# Class: sad
# Confidence Score: 0.9949373
# --------------------
# 1/1 [==============================] - 0s 39ms/step
# Image: sad-man-holding-head-with-hand_1150-6345.jpg
# Class: angry
# Confidence Score: 0.9976023
# --------------------
# 1/1 [==============================] - 0s 40ms/step
# Image: depositphotos_86851530-stock-photo-close-up-of-african-young.jpg
# Class: sad
# Confidence Score: 0.9968554
# --------------------
# 1/1 [==============================] - 0s 42ms/step
# Image: portrait-sad-man-260nw-126009806.jpg
# Class: sad
# Confidence Score: 0.9980927
# --------------------
# 1/1 [==============================] - 0s 38ms/step
# Image: sad.jpg
# Class: sad
# Confidence Score: 0.9998964
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: crying-sad.gif
# Class: angry
# Confidence Score: 0.92317665
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: lonely-depressed-person-sitting-near-brick-wall_181624-30778.jpg
# Class: sad
# Confidence Score: 0.99912304
# --------------------
# 1/1 [==============================] - 0s 41ms/step
# Image: sad-quotes-about-life.jpg
# Class: sad
# Confidence Score: 0.99918133
# --------------------
# 1/1 [==============================] - 0s 38ms/step
# Image: Make-someone-sad-happy.jpg
# Class: sad
# Confidence Score: 0.999998
# --------------------
# 1/1 [==============================] - 0s 45ms/step
# Image: rtor_guest-blog_fetured-image_Depression-versus-Sadness-How-to-Recognize-and-Cope.jpg
# Class: sad
# Confidence Score: 0.9999987
# --------------------
# 1/1 [==============================] - 0s 38ms/step
# Image: sad-looking-man.jpg
# Class: sad
# Confidence Score: 0.9678393
# --------------------
# 1/1 [==============================] - 0s 38ms/step
# Image: very-sad-man-sitting-alone-on-white-background-depressed-young-man-sitting-businessman-vector.jpg
# Class: sad
# Confidence Score: 0.9902082
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: depositphotos_11207956-stock-photo-thoughtful-man-in-the-living.jpg
# Class: sad
# Confidence Score: 0.999961
# --------------------
# 1/1 [==============================] - 0s 36ms/step
# Image: sad-woman.jpg
# Class: sad
# Confidence Score: 0.9998907
# --------------------
# 1/1 [==============================] - 0s 36ms/step
# Image: How-To-Make-Someone-Happy-When-Theyre-Sad.jpg
# Class: sad
# Confidence Score: 0.62253904
# --------------------
# 1/1 [==============================] - 0s 39ms/step
# Image: 640px-Crying-girl.jpg
# Class: sad
# Confidence Score: 0.99767834
# --------------------
# 1/1 [==============================] - 0s 41ms/step
# Image: sad-people-icon-2CCHXB2.jpg
# Class: sad
# Confidence Score: 0.9988133
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: -unhappy-miss-good-chance-dressed-casually-isolated-yellow-wall_273609-37534.jpg
# Class: sad
# Confidence Score: 0.73505753
# --------------------
# 1/1 [==============================] - 0s 40ms/step
# Image: sadness.jpg
# Class: sad
# Confidence Score: 0.99976856
# --------------------
# 1/1 [==============================] - 0s 42ms/step
# Image: Sadder-not-wiser_AdobeStock_219682170.jpg
# Class: sad
# Confidence Score: 0.9999875
# --------------------
# 1/1 [==============================] - 0s 40ms/step
# Image: dark-depression-mood-people-wallpaper-preview.jpg
# Class: sad
# Confidence Score: 0.9997038
# --------------------
# 1/1 [==============================] - 0s 38ms/step
# Image: image-20160914-4963-19knfh1.jpg
# Class: sad
# Confidence Score: 0.99950695
# --------------------
# 1/1 [==============================] - 0s 39ms/step
# Image: 766x415_Depression_vs_Sadness-1-732x415.jpg
# Class: sad
# Confidence Score: 0.9973514
# --------------------
# 1/1 [==============================] - 0s 39ms/step
# Image: aid12707023-v4-1200px-Make-a-Sad-Person-Happy-Step-10.jpg
# Class: sad
# Confidence Score: 0.98917574
# --------------------
# 1/1 [==============================] - 0s 36ms/step
# Image: sad-people-vector-26812552.jpg
# Class: sad
# Confidence Score: 0.99964666
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: 20201112-Alexithymia-844.jpg
# Class: sad
# Confidence Score: 0.9966061
# --------------------
# 1/1 [==============================] - 0s 38ms/step
# Image: file-20211126-25-4jc5ds.jpeg
# Class: sad
# Confidence Score: 0.9995969
# --------------------
# 1/1 [==============================] - 0s 40ms/step
# Image: a-man-who-suffers-from-seasonal-affective-disorder-walking-down-a-foggy-road.jpg
# Class: sad
# Confidence Score: 0.99987483
# --------------------
# 1/1 [==============================] - 0s 48ms/step
# Image: image18.jpeg
# Class: sad
# Confidence Score: 0.97406703
# --------------------
# 1/1 [==============================] - 0s 39ms/step
# Image: 1694806.jpg
# Class: sad
# Confidence Score: 0.999943
# --------------------
# 1/1 [==============================] - 0s 40ms/step
# Image: Sad-man-sitting-in-bedroom-header.jpg
# Class: sad
# Confidence Score: 0.9999943
# --------------------
# 1/1 [==============================] - 0s 38ms/step
# Image: CC_HE_1221887081_SituationalDepression-650x428.jpg
# Class: sad
# Confidence Score: 0.9978509
# --------------------
# 1/1 [==============================] - 0s 40ms/step
# Image: sadness-inside-out-today-main-tease-191018.jpg
# Class: happy
# Confidence Score: 0.92979586
# --------------------
# 1/1 [==============================] - 0s 39ms/step
# Image: mental-health_1200_getty.jpg
# Class: sad
# Confidence Score: 0.9999913
# --------------------
# 1/1 [==============================] - 0s 40ms/step
# Image: man-portrait-contemplative-sad-looking-at-camera-732x549-thumbnail.jpg
# Class: sad
# Confidence Score: 0.999193
# --------------------
# 1/1 [==============================] - 0s 36ms/step
# Image: upsetman.jpg
# Class: sad
# Confidence Score: 0.9973084
# --------------------
# 1/1 [==============================] - 0s 39ms/step
# Image: depressed-man-studio-shot-260nw-404652526.jpg
# Class: sad
# Confidence Score: 0.99967265
# --------------------
# 1/1 [==============================] - 0s 49ms/step
# Image: man-tears-tear-look.jpg
# Class: sad
# Confidence Score: 0.99528104
# --------------------
# 1/1 [==============================] - 0s 39ms/step
# Image: man-with-head-down-300x300.jpg
# Class: sad
# Confidence Score: 0.99999976
# --------------------
# 1/1 [==============================] - 0s 39ms/step
# Image: iStock_000001932580XSmall.jpg
# Class: sad
# Confidence Score: 0.997079
# --------------------
# 1/1 [==============================] - 0s 38ms/step
# Image: 5acf9ed1146e711e008b46d7.jpg
# Class: sad
# Confidence Score: 0.7394868
# --------------------
# 1/1 [==============================] - 0s 65ms/step
# Image: coronavirus-depression-hero.jpg
# Class: sad
# Confidence Score: 0.76671267
# --------------------
# 1/1 [==============================] - 0s 57ms/step
# Image: what-successful-people-do-when-they-are-sad-1200x900.jpg
# Class: sad
# Confidence Score: 0.99742633
# --------------------
# 1/1 [==============================] - 0s 58ms/step
# Image: 73705bd7debb66c2afc780a22c223804.jpg
# Class: sad
# Confidence Score: 0.9972989
# --------------------
# 1/1 [==============================] - 0s 56ms/step
# Image: sue.jpg
# Class: sad
# Confidence Score: 0.9990067
# --------------------
# 1/1 [==============================] - 0s 85ms/step
# Image: sad-glance-mm-nisan-kandilcioglu.jpg
# Class: sad
# Confidence Score: 0.99967754
# --------------------
# 1/1 [==============================] - 0s 57ms/step
# Image: 39843138-sad-man.jpg
# Class: sad
# Confidence Score: 0.99519473
# --------------------
# 1/1 [==============================] - 0s 59ms/step
# Image: screen-shot-2014-07-31-at-6-09-12-pm.png
# Class: sad
# Confidence Score: 0.9989644
# --------------------
# 1/1 [==============================] - 0s 57ms/step
# Image: crying-at-work.jpg
# Class: sad
# Confidence Score: 0.99576426
# --------------------
# 1/1 [==============================] - 0s 61ms/step
# Image: all-those-people-who-are-sad-17573-1.jpg
# Class: sad
# Confidence Score: 0.99944717
# --------------------
# 1/1 [==============================] - 0s 36ms/step
# Image: vector-sad-man-sitting-silhouette.jpg
# Class: sad
# Confidence Score: 0.9829795
# --------------------
# 1/1 [==============================] - 0s 44ms/step
# Image: 107188144-1675355909384-gettyimages-1302154722-dsc_9175.jpeg
# Class: sad
# Confidence Score: 0.99815506
# --------------------
# 1/1 [==============================] - 0s 38ms/step
# Image: what-to-say-to-someone-whos-depressed.jpg
# Class: sad
# Confidence Score: 0.9948868
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: sad-people-group-therapy-session_23-2148752071.jpg
# Class: sad
# Confidence Score: 0.99922144
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: 09-113216-depressed_people_listen_to_sad_music_to_calm_and_uplift_says_study.jpg
# Class: sad
# Confidence Score: 0.9996617
# --------------------
# 1/1 [==============================] - 0s 41ms/step
# Image: n-rendering-frustrated-upset-man-sitting-white-people-man-character-53250684.jpg
# Class: sad
# Confidence Score: 0.9999306
# --------------------
# 1/1 [==============================] - 0s 50ms/step
# Image: pexels-photo-4584665.jpeg
# Class: angry
# Confidence Score: 0.98517275
# --------------------
# 1/1 [==============================] - 0s 42ms/step
# Image: dreamstime_s_101440985.jpg
# Class: sad
# Confidence Score: 0.99998474
# --------------------
# 1/1 [==============================] - 0s 41ms/step
# Image: sad-quotes-lead-image-1677524157.jpg
# Class: sad
# Confidence Score: 1.0
# --------------------
# 1/1 [==============================] - 0s 40ms/step
# Image: person-super-depressed.jpg
# Class: sad
# Confidence Score: 0.99999845
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: _2539df08-4f50-11e6-85e3-522dd231fa74.jpg
# Class: sad
# Confidence Score: 0.99362624
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: Science_robotgait_124649246.jpg
# Class: sad
# Confidence Score: 1.0
# --------------------
# 1/1 [==============================] - 0s 41ms/step
# Image: image-asset.jpeg
# Class: sad
# Confidence Score: 0.9999044
# --------------------
# 1/1 [==============================] - 0s 38ms/step
# Image: secret-signs-of-loneliness-01-1440x810.jpg
# Class: sad
# Confidence Score: 0.99717855
# --------------------
# 1/1 [==============================] - 0s 41ms/step
# Image: b2ap3_large_happy-sad-unsplash-850x575.jpg
# Class: sad
# Confidence Score: 0.99855286
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: people-1492052_1920-1024x681.jpg
# Class: sad
# Confidence Score: 0.99837625
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: isolated-girl-crying-over-makeup-sad-person-concept-isolated-white-174239618.jpg
# Class: sad
# Confidence Score: 0.95056456
# --------------------
# 1/1 [==============================] - 0s 38ms/step
# Image: sad-people.jpg
# Class: sad
# Confidence Score: 0.9999349
# --------------------
# 1/1 [==============================] - 0s 43ms/step
# Image: 0x0.jpg
# Class: sad
# Confidence Score: 0.9994405
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: strated-depressed-man-sitting-on-plastic-stool-3d-white-people-man-character.jpg
# Class: sad
# Confidence Score: 0.99999607
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: 405-4050267_sad-people-png-sad-person-transparent-background-png.png
# Class: sad
# Confidence Score: 0.99735814
# --------------------
# 1/1 [==============================] - 0s 38ms/step
# Image: depression-1020x680.jpg
# Class: sad
# Confidence Score: 0.9999746
# --------------------
# 1/1 [==============================] - 0s 35ms/step
# Image: african-american-depressive-sad-broken-260nw-475790911.jpg
# Class: sad
# Confidence Score: 0.99981576
# --------------------
# 1/1 [==============================] - 0s 39ms/step
# Image: png-transparent-woman-sad-folklore-ghost-horror-spirit-vendetta-vengeance-girl-person-thumbnail.png
# Class: sad
# Confidence Score: 0.9999801
# --------------------
# 1/1 [==============================] - 0s 43ms/step
# Image: 360_F_548848756_IlV9Y9HV8chb6mSuc3PBamYRT9gIn8Vo.jpg
# Class: sad
# Confidence Score: 0.99977344
# --------------------
# 1/1 [==============================] - 0s 36ms/step
# Image: 7RNXwSxCAKL8vGtXG2ZkyD-1200-80.jpg
# Class: sad
# Confidence Score: 0.9993931
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: sad-person-concept-vector-26538685.jpg
# Class: sad
# Confidence Score: 0.98036397
# --------------------
# 1/1 [==============================] - 0s 36ms/step
# Image: sad-person-pictures-2bnso9uiwlhrikrx.jpg
# Class: sad
# Confidence Score: 0.99997485
# --------------------
# 1/1 [==============================] - 0s 37ms/step
# Image: Seasonal-affective-disorder.png
# Class: sad
# Confidence Score: 0.99947304
# --------------------

# %%
# Predicts the model
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# Class: sad
# Confidence Score: 0.99947304

# %%
# prompt: 웹캠을 이용한 서비스 예측

from keras.models import load_model
from PIL import Image, ImageOps
import numpy as np
import tensorflow as tf
from PIL import Image
import io
from google.colab import files

# 모델 로드
model = tf.keras.models.load_model('keras_model.h5')

# 이미지 전처리 함수
def preprocess_image(image_bytes):
    try:
        image = Image.open(io.BytesIO(image_bytes))
        image = image.resize((224, 224))
        image = np.array(image) / 255.0
        image = np.expand_dims(image, axis=0)
        return image
    except Exception as e:
        print(f"Error preprocessing image: {e}")
        return None

# 예측 함수
def predict(image_bytes):
    preprocessed_image = preprocess_image(image_bytes)
    if preprocessed_image is None:
        return None

    predictions = model.predict(preprocessed_image)
    predicted_class = np.argmax(predictions[0])
    confidence = predictions[0][predicted_class]

    # 클래스 이름 매핑 (Teachable Machine에서 사용한 클래스 이름으로 변경)
    class_names = ['sad', 'happy', 'angry']  # 실제 클래스 이름으로 수정
    predicted_class_name = class_names[predicted_class]

    return predicted_class_name, confidence
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# 웹캠 이미지 캡처 및 예측 (Google Colab에서 실행)
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
try:
  filename = take_photo()
  # filename = '106.jpg'
  print('Saved to {}'.format(filename))

  with open(filename, "rb") as f:
    image_bytes = f.read()
    predicted_class_name, confidence = predict(image_bytes)
    if predicted_class_name:
        print(f"Predicted class: {predicted_class_name}, Confidence: {confidence}")
    else:
        print("Prediction failed")

except Exception as err:
  print(str(err))
# Out:
# NotAllowedError: Permission denied
